# %%
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
import numpy as np
import argparse
# Out:
# Using TensorFlow backend.
# /data/tangle/pyimagesearch/venv/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
image = load_img("jemma.png")

# %%
image
# Out:
# <PIL.Image.Image image mode=RGB size=278x207 at 0x7F0426D787F0>

# %%
image = img_to_array(image)
image = np.expand_dims(image, axis=0)

# %%
image.shape
# Out:
# (1, 207, 278, 3)

# %%
aug = ImageDataGenerator(rotation_range=30, width_shift_range=0.1,
                        height_shift_range=0.1, shear_range=0.2, zoom_range=0.2,
                        horizontal_flip=True, fill_mode="nearest")

# %%
total = 0
imageGen = aug.flow(image, batch_size=1, save_to_dir='.', save_prefix='image', save_format='jpg')

for image in imageGen:
    total += 1
    if total == 10:
        break
